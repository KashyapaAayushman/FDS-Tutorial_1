# %%
import numpy as np

array = np.array([[1+2j, 2+3j, 3+4j], [4+5j, 5+6j, 6+7j]])

print("Flags:")
print(array.flags)
print()

print("Shape:", array.shape)
print()


print("Strides:", array.strides)
print()

print("Number of dimensions:", array.ndim)
print()

print("Data pointer:", array.data)
print()

print("Size:", array.size)
print()


print("Item size:", array.itemsize, "bytes")
print()

print("Base object:", array.base)
print()

print("Total bytes:", array.nbytes)
print()

print("Transpose:")
print(array.T)
print()

print("Real part:")
print(array.real)
print()

print("Imaginary part:")
print(array.imag)
print()
# Out:
# Flags:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : False
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#
#
# Shape: (2, 3)
#
# Strides: (48, 16)
#
# Number of dimensions: 2
#
# Data pointer: <memory at 0x000001EB8ECA4A00>
#
# Size: 6
#
# Item size: 16 bytes
#
# Base object: None
#
# Total bytes: 96
#
# Transpose:
# [[1.+2.j 4.+5.j]
#  [2.+3.j 5.+6.j]
#  [3.+4.j 6.+7.j]]
#
# Real part:
# [[1. 2. 3.]
#  [4. 5. 6.]]
#
# Imaginary part:
# [[2. 3. 4.]
#  [5. 6. 7.]]
